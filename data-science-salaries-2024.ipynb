# %%
#Packages for Data Processing and Cleaning
import numpy as np # linear algebra
import pandas as pd 
import os

# %% [markdown]
# **Loading the Dataset**

# %%
df = pd.read_csv('/Users/georgiosskourlis/Documents/DataScience_salaries_2024.csv')

df.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L
# 2               HU            L
# 3               JP            S
# 4               IN            L

# %% [markdown]
# **Checking for Nulls**

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# **Data Overview**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  int64
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary              14838 non-null  int64
#  5   salary_currency     14838 non-null  object
#  6   salary_in_usd       14838 non-null  int64
#  7   employee_residence  14838 non-null  object
#  8   remote_ratio        14838 non-null  int64
#  9   company_location    14838 non-null  object
#  10  company_size        14838 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# **Creating Job Categories**

# %%
# Simplifies job titles to broader job category labels and creates an original column.

# Mapping job titles to job categories.
def map_job_title(df, original_column='job_title', new_column='job_category'):

    # Define the mapping dictionary
    job_title_mapping = {
        'data analyst': 'Data Analyst',
        'bi analyst': 'Data Analyst',
        'analytics': 'Data Analyst',
        'data scientist': 'Data Scientist',
        'data science': 'Data Scientist',
        'decision scientist': 'Data Scientist',
        'data engineer': 'Data Engineer',
        'etl': 'Data Engineer',
        'pipeline': 'Data Engineer',
        'machine learning': 'ML Engineer',
        'ml': 'ML Engineer',
        'deep learning': 'ML Engineer',
        'ai': 'ML Engineer',
        'data architect': 'Data Engineer',
        'big data': 'Data Engineer',
        'cloud data': 'Data Engineer',
        'data manager': 'Data Engineer',
        'head of data': 'Data Engineer',
        'director': 'Data Engineer',
        'bi developer': 'Data Analyst',
        'power bi': 'Data Analyst',
        'business intelligence': 'Data Analyst',
        'research scientist': 'Data Scientist',
        'research engineer': 'Data Scientist',
        'statistician': 'Data Analyst',
        'quantitative': 'Data Analyst',
        'computational biologist': 'Data Scientist',
        'robotics': 'Data Engineer',
        'nlp': 'Data Engineer',
        'applied scientist': 'Data Scientist',
        'research analyst': 'Data Analyst',
        'data specialist ': 'Data Scientist',
        'data modeler': 'Data Engineer',
    }

    # Convert job titles to lowercase and map them to broader categories
    df[new_column] = df[original_column].str.lower().apply(
        lambda title: next((v for k, v in job_title_mapping.items() if k in title), 'Data Scientist')
    )
    return df

# Example usage
df = map_job_title(df)

# %% [markdown]
# **Output**

# %%
df['job_category']
# Out:
# 0        Data Scientist
# 1          Data Analyst
# 2        Data Scientist
# 3           ML Engineer
# 4           ML Engineer
#               ...
# 14833      Data Analyst
# 14834      Data Analyst
# 14835       ML Engineer
# 14836      Data Analyst
# 14837       ML Engineer
# Name: job_category, Length: 14838, dtype: object

# %% [markdown]
# **Redefining Work Models**

# %%
# Converts remote ratio to work models labels and creates an original column.

# Mapping remote ratio to work models.
def map_remote_ratio(df, original_column='remote_ratio', new_column='work_model'):

    # Define the mapping dictionary
    remote_ratio_mapping = {
        0: 'In-Person',
        50: 'Hybrid',
        100: 'Remote'
    }

    # Apply the mapping with a default value of 'Other' for unmapped numbers
    df[new_column] = df[original_column].map(remote_ratio_mapping).fillna('Other')

    return df

# Example usage
df = map_remote_ratio(df)

# %% [markdown]
# **Output**

# %%
df['work_model']
# Out:
# 0           Remote
# 1           Hybrid
# 2           Hybrid
# 3           Hybrid
# 4           Hybrid
#            ...
# 14833       Remote
# 14834    In-Person
# 14835       Remote
# 14836    In-Person
# 14837       Remote
# Name: work_model, Length: 14838, dtype: object

# %% [markdown]
# **Categorizing Experience Level**

# %%
# Converts experience levels into more descriptive names.

# Mapping experience levels to more descriptive labels.
def map_experience_level(df, original_column='experience_level', new_column='generalized_experience_level'):

    # Define the mapping dictionary
    experience_level_mapping = {
        'EN': 'Junior',
        'MI': 'Mid-Level',
        'SE': 'Senior',
        'EX': 'Expert'
    }

    # Create the new column
    df[new_column] = df[original_column].replace(experience_level_mapping)
    return df

# Example usage
df = map_experience_level(df)

# %% [markdown]
# **Output**

# %%
df['generalized_experience_level']
# Out:
# 0        Mid-Level
# 1        Mid-Level
# 2        Mid-Level
# 3        Mid-Level
# 4           Senior
#            ...
# 14833    Mid-Level
# 14834       Expert
# 14835       Junior
# 14836       Junior
# 14837       Junior
# Name: generalized_experience_level, Length: 14838, dtype: object

# %% [markdown]
# **Checking for Distinct Employment Types**

# %%
grouped_counts = df.groupby('employment_type').size()
grouped_counts
# Out:
# employment_type
# CT       26
# FL       13
# FT    14772
# PT       27
# dtype: int64

# %% [markdown]
# **Converting Employment Types**

# %%
#Converting Acronyms to Full Employment Type status
def convert_status(value):
    if value == 'FT':
        return 'Full Time'
    elif value == 'PT':
        return 'Part Time'
    elif value == 'CT':
        return 'Contract'
    elif value == 'FL':
        return 'Freelance'
    else:
        return value  # Keeps other values unchanged

df['employment_type'] = df['employment_type'].apply(convert_status)

# %% [markdown]
# **Output**

# %%
df['employment_type']
# Out:
# 0        Full Time
# 1        Full Time
# 2        Full Time
# 3        Full Time
# 4        Full Time
#            ...
# 14833    Full Time
# 14834    Full Time
# 14835    Full Time
# 14836    Full Time
# 14837    Part Time
# Name: employment_type, Length: 14838, dtype: object

# %% [markdown]
# **Checking For Negative Values**

# %%
undesired_values = df[df['salary'] <= 0].sort_values('salary', ascending=False).count()

undesired_values_df = undesired_values.reset_index()

undesired_values_df.columns = ['Salary', 'Count']

undesired_values_df
# Out:
#                           Salary  Count
# 0                      work_year      0
# 1               experience_level      0
# 2                employment_type      0
# 3                      job_title      0
# 4                         salary      0
# 5                salary_currency      0
# 6                  salary_in_usd      0
# 7             employee_residence      0
# 8                   remote_ratio      0
# 9               company_location      0
# 10                  company_size      0
# 11                  job_category      0
# 12                    work_model      0
# 13  generalized_experience_level      0

# %% [markdown]
# **Data Frame Ready for Analysis**

# %%
df.head(50)
# Out:
#     work_year experience_level employment_type  \
# 0        2021               MI       Full Time
# 1        2021               MI       Full Time
# 2        2020               MI       Full Time
# 3        2021               MI       Full Time
# 4        2022               SE       Full Time
# 5        2021               MI       Full Time
# 6        2021               SE       Full Time
# 7        2022               EN       Full Time
# 8        2022               EX       Full Time
# 9        2022               EN       Full Time
# 10       2023               MI       Full Time
# 11       2023               EN       Full Time
# 12       2021               SE       Full Time
# 13       2022               SE       Full Time
# 14       2020               EN       Full Time
# 15       2022               MI       Full Time
# 16       2023               EN       Full Time
# 17       2021               SE       Full Time
# 18       2021               SE       Full Time
# 19       2023               SE       Full Time
# 20       2024               MI       Full Time
# 21       2023               MI       Full Time
# 22       2023               MI       Full Time
# 23       2023               SE       Full Time
# 24       2022               SE       Full Time
# 25       2021               SE       Full Time
# 26       2020               MI       Full Time
# 27       2022               MI       Full Time
# 28       2023               MI       Full Time
# 29       2022               MI       Full Time
# 30       2021               MI       Full Time
# 31       2022               MI       Freelance
# 32       2022               MI       Full Time
# 33       2024               MI       Full Time
# 34       2021               EN       Full Time
# 35       2021               EN       Full Time
# 36       2021               EN       Full Time
# 37       2023               EN       Full Time
# 38       2023               MI       Full Time
# 39       2022               EN       Full Time
# 40       2021               SE       Full Time
# 41       2023               EN       Full Time
# 42       2023               MI       Full Time
# 43       2021               MI       Full Time
# 44       2022               MI       Full Time
# 45       2021               EN       Full Time
# 46       2023               SE       Full Time
# 47       2023               MI       Full Time
# 48       2021               MI       Full Time
# 49       2023               MI       Full Time
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# 4       Lead Machine Learning Engineer   7500000             INR
# 5                          ML Engineer   7000000             JPY
# 6                 Data Science Manager   7000000             INR
# 7                       Data Scientist   6600000             HUF
# 8             Head of Machine Learning   6000000             INR
# 9                    Research Engineer   5500000             JPY
# 10                Head of Data Science   5000000             INR
# 11                       AI Programmer   4950806             INR
# 12           Machine Learning Engineer   4900000             INR
# 13                 Lead Data Scientist   4460000             INR
# 14                       Data Engineer   4450000             JPY
# 15                      Data Scientist   4200000             INR
# 16  Applied Machine Learning Scientist   4000000             INR
# 17                      Data Scientist   4000000             INR
# 18                Data Science Manager   4000000             INR
# 19                Data Science Manager   3600000             INR
# 20                   Lead Data Analyst   3300000             INR
# 21                Data Science Manager   3200000             INR
# 22              Data Analytics Manager   3200000             INR
# 23         Data Integration Specialist   3000000             INR
# 24            Principal Data Architect   3000000             INR
# 25                 Lead Data Scientist   3000000             INR
# 26                      Data Scientist   3000000             INR
# 27                       Data Engineer   2800000             INR
# 28                        NLP Engineer   2700000             INR
# 29                      Data Scientist   2500000             INR
# 30                      Data Scientist   2500000             INR
# 31  Applied Machine Learning Scientist   2400000             INR
# 32                      Data Scientist   2400000             INR
# 33                   Big Data Engineer   2300000             INR
# 34                       Data Engineer   2250000             INR
# 35                      Data Scientist   2200000             INR
# 36                      Data Scientist   2100000             INR
# 37                AI Research Engineer   2000000             INR
# 38  Machine Learning Software Engineer   2000000             INR
# 39                      Data Scientist   1800000             INR
# 40           Machine Learning Engineer   1799997             INR
# 41                        Data Analyst   1700000             INR
# 42              Applied Data Scientist   1700000             INR
# 43                   Big Data Engineer   1672000             INR
# 44           Machine Learning Engineer   1650000             INR
# 45                       Data Engineer   1600000             INR
# 46                        AI Scientist   1500000             ILS
# 47                   Lead Data Analyst   1500000             INR
# 48                   Lead Data Analyst   1450000             INR
# 49                 Data Analytics Lead   1440000             INR
#
#     salary_in_usd employee_residence  remote_ratio company_location  \
# 0           40038                 CL           100               CL
# 1           36259                 HU            50               US
# 2           35735                 HU            50               HU
# 3           77364                 JP            50               JP
# 4           95386                 IN            50               IN
# 5           63711                 JP            50               JP
# 6           94665                 IN            50               IN
# 7           17684                 HU           100               HU
# 8           76309                 IN            50               IN
# 9           41809                 JP            50               JP
# 10          60805                 IN            50               IN
# 11          60207                 IN             0               IN
# 12          66265                 IN             0               IN
# 13          56723                 IN             0               IN
# 14          41689                 JP           100               JP
# 15          53416                 IN           100               ID
# 16          48644                 IN           100               DE
# 17          54094                 IN           100               IN
# 18          54094                 IN            50               US
# 19          43779                 IN           100               IN
# 20          39615                 IN            50               IN
# 21          38915                 IN            50               IN
# 22          38915                 IN            50               IN
# 23          36483                 IN            50               IN
# 24          38154                 IN           100               IN
# 25          40570                 IN            50               IN
# 26          40481                 IN             0               IN
# 27          35610                 IN            50               IN
# 28          32834                 IN           100               IN
# 29          31795                 IN           100               US
# 30          33808                 IN             0               IN
# 31          30523                 IN           100               IN
# 32          30523                 IN           100               IN
# 33          27611                 IN           100               IN
# 34          30428                 IN           100               IN
# 35          29751                 IN            50               IN
# 36          28399                 IN           100               IN
# 37          24322                 IN           100               CH
# 38          24322                 IN            50               IN
# 39          22892                 IN            50               IN
# 40          24342                 IN           100               IN
# 41          20673                 IN            50               IN
# 42          20673                 IN           100               IN
# 43          22611                 IN             0               IN
# 44          20984                 IN            50               IN
# 45          21637                 IN            50               IN
# 46         417937                 IL             0               IL
# 47          18241                 IN            50               IN
# 48          19609                 IN           100               IN
# 49          17511                 IN            50               SG
#
#    company_size    job_category work_model generalized_experience_level
# 0             L  Data Scientist     Remote                    Mid-Level
# 1             L    Data Analyst     Hybrid                    Mid-Level
# 2             L  Data Scientist     Hybrid                    Mid-Level
# 3             S     ML Engineer     Hybrid                    Mid-Level
# 4             L     ML Engineer     Hybrid                       Senior
# 5             S     ML Engineer     Hybrid                    Mid-Level
# 6             L  Data Scientist     Hybrid                       Senior
# 7             M  Data Scientist     Remote                       Junior
# 8             L     ML Engineer     Hybrid                       Expert
# 9             L  Data Scientist     Hybrid                       Junior
# 10            L  Data Scientist     Hybrid                    Mid-Level
# 11            S     ML Engineer  In-Person                       Junior
# 12            L     ML Engineer  In-Person                       Senior
# 13            L  Data Scientist  In-Person                       Senior
# 14            S   Data Engineer     Remote                       Junior
# 15            L  Data Scientist     Remote                    Mid-Level
# 16            L     ML Engineer     Remote                       Junior
# 17            L  Data Scientist     Remote                       Senior
# 18            L  Data Scientist     Hybrid                       Senior
# 19            L  Data Scientist     Remote                       Senior
# 20            L    Data Analyst     Hybrid                    Mid-Level
# 21            L  Data Scientist     Hybrid                    Mid-Level
# 22            M    Data Analyst     Hybrid                    Mid-Level
# 23            L  Data Scientist     Hybrid                       Senior
# 24            L   Data Engineer     Remote                       Senior
# 25            L  Data Scientist     Hybrid                       Senior
# 26            L  Data Scientist  In-Person                    Mid-Level
# 27            L   Data Engineer     Hybrid                    Mid-Level
# 28            M   Data Engineer     Remote                    Mid-Level
# 29            M  Data Scientist     Remote                    Mid-Level
# 30            M  Data Scientist  In-Person                    Mid-Level
# 31            S     ML Engineer     Remote                    Mid-Level
# 32            L  Data Scientist     Remote                    Mid-Level
# 33            L   Data Engineer     Remote                    Mid-Level
# 34            L   Data Engineer     Remote                       Junior
# 35            L  Data Scientist     Hybrid                       Junior
# 36            M  Data Scientist     Remote                       Junior
# 37            L     ML Engineer     Remote                       Junior
# 38            L     ML Engineer     Hybrid                    Mid-Level
# 39            M  Data Scientist     Hybrid                       Junior
# 40            L     ML Engineer     Remote                       Senior
# 41            L    Data Analyst     Hybrid                       Junior
# 42            L  Data Scientist     Remote                    Mid-Level
# 43            L   Data Engineer  In-Person                    Mid-Level
# 44            L     ML Engineer     Hybrid                    Mid-Level
# 45            M   Data Engineer     Hybrid                       Junior
# 46            L     ML Engineer  In-Person                       Senior
# 47            L    Data Analyst     Hybrid                    Mid-Level
# 48            L    Data Analyst     Remote                    Mid-Level
# 49            M    Data Analyst     Hybrid                    Mid-Level
